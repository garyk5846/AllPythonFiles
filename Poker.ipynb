# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
Day=pd.read_excel('Poker.xlsx','Day',index_col=0)
Hour=pd.read_excel('Poker.xlsx','Hour')
Dayhour=pd.read_excel('Poker.xlsx','DayHour')
Cards=pd.read_excel('Poker.xlsx','Cards')
#JUST CHANGING THIS NOW- TEST

# %%
plt.style.use('dark_background')
Day['Won'].plot.hist(figsize=(8,10),title="Gary's $Won by Day(Positive only)",grid=True,
                    legend=True,style='--',xlim=(0,20000),fontsize=9,color='peachpuff',alpha=0.5)

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
Day.plot.hist()

# %%
plt.style.use('bmh')
Day.plot.barh()

# %%
x=Day['Hands']
y=Day['Won']

# %%
#OO Method
fig=plt.figure()
#Takes in fuor arguments, left bottom width height[0....1]
#EG below is 10% from left, 10% from bottom, width of 0.8, height of 0.8
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(y,x)

# %%
Hour
# Out:
#     Hour   Hands         Won       EVWon      bb100    Evbb100
# 0      8     766   -445.5056   -165.6092 -29.080000 -10.810000
# 1      9     419   -254.7520   -254.7520 -30.400000 -30.400000
# 2     10    8472  -2318.2344  -1643.3442 -13.681742  -9.698679
# 3     11   19197    832.3502   1299.3528   2.167917   3.384260
# 4     12   29170  -4945.4870  -4005.8118  -8.477009  -6.866321
# 5     13   17009   2665.5504   1644.5806   7.835706   4.834442
# 6     14    9283   1913.4264   1608.8888  10.306078   8.665780
# 7     15   15981   1040.8786   1047.0510   3.256613   3.275925
# 8     16   36643   1895.6996   -187.5582   2.586715  -0.255926
# 9     17  140596   4055.2766   5005.6098   1.442174   1.780139
# 10    18  237653   8796.4652   7318.1344   1.850695   1.539668
# 11    19   92810   8537.4784   7725.9488   4.599439   4.162239
# 12    20  149759   9592.8782  12232.4082   3.202772   4.084031
# 13    21  101229   1918.8670   1672.1728   0.947785   0.825936
# ...

# %%
x=Hour['Hour']
y=Hour['Won']

# %%
#OO Method
fig=plt.figure()
#Takes in fuor arguments, left bottom width height[0....1]
#EG below is 10% from left, 10% from bottom, width of 0.8, height of 0.8
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)

# %%
#Adding a second axes
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.2,0.5,0.5])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.4,0.4,0.9,0.9])

# %%
#Plotting ont hese
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.2,0.5,0.5])
axes1.plot(x,y)
axes1.set_title("Amount won by Time of Day")
axes2.plot(y,x)
axes2.set_title("Time of Day by Amount Won")
# Out:
# Text(0.5, 1.0, 'Time of Day by Amount Won')

# %%
#subplots with OO using tuple unpacking
fig,axes = plt.subplots(nrows=3,ncols=4)

# %%
fig,axes = plt.subplots(nrows=3,ncols=4)
plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
#fig defines the figure, axes can be iterated through
axes[0].plot(x,y)
axes[0].set_title('Won by Time of day')
axes[1].plot(y,x)
axes[1].set_title('Time of day by amount won')
# Out:
# Text(0.5, 1.0, 'Time of day by amount won')

# %%
#defining figsize
fig=plt.figure(figsize=(5,2))
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,figsize=(5,2))
axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
fig.savefig('my_picture.png')
