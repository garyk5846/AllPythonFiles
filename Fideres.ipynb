# %%
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser
def convert_pdf_to_string(file_path):

    output_string = StringIO()
    with open(file_path, 'rb') as in_file:
        parser = PDFParser(in_file)
        doc = PDFDocument(parser)
        rsrcmgr = PDFResourceManager()
        device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        for page in PDFPage.create_pages(doc):
            interpreter.process_page(page)

    return(output_string.getvalue())

# %%
file_path = 'C:/Users/garyp/Downloads/Fideres Data Analysis Assessment - Q1.1 Attachment.pdf'
x=convert_pdf_to_string(file_path)

# %%
x.split('\n')
# Out:
# ['Security Name ',
#  ' ',
#  'Coupon Rate ',
#  'Fail Description ',
#  '',
#  ' ',
#  ' ',
#  'Maturity Date ',
#  ' ',
#  '',
#  'XYZ COMMON STOCK ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  'XYZ COMMON STOCK ',
#  ' ',
#  ' ',
#  ' ',
#  '',
#  'Security ID ',
#  'ISIN ',
#  'OCC ID ',
#  ' ',
#  'Trade Date: 19-Sep-2017 CCY: EUR ',
#  ' Transaction Category: SALE Transaction Status: Settled ',
#  '7508927 ',
#  'DE0007472060 ',
#  ' ',
#  ' ',
#  'Trade Date: 11-Oct-2017 CCY: EUR ',
#  ' Transaction Category: SALE Transaction Status: Settled ',
#  '7508927 ',
#  'DE0007472060 ',
#  ' ',
#  ' ',
#  'Trade Date: 07-Nov-2017 CCY: EUR ',
#  ' Transaction Category: SALE Transaction Status: Settled ',
#  '7508927 ',
#  'DE0007472060 ',
#  ' ',
#  ' ',
#  'Trade Date: 13-Nov-2017 CCY: EUR ',
#  ' Transaction Category: SALE Transaction Status: Settled ',
#  '7508927 ',
#  'DE0007472060 ',
#  ' ',
#  ' ',
#  '7508927 ',
#  'DE0007472060 ',
#  ' ',
#  ' ',
#  '7508927 ',
#  'DE0007472060 ',
# ...

# %%
path = 'C:/Users/garyp/Downloads/Fideres Data Analysis Assessment - Q1.1 Attachment.pdf'
convert_pdf_to_txt(path)

# %%
import PyPDF2
import numpy as np
import pandas as pd
path = 'C:/Users/garyp/Downloads/Fideres Data Analysis Assessment - Q1.1 Attachment.pdf'
with open(path, mode='rb') as f:
    reader = PyPDF2.PdfFileReader(f)
    page = reader.getPage(0).extractText()
page.split('\n')
# Out:
# ['Security ID',
#  ' ',
#  'Security Name',
#  ' ',
#  ' ',
#  ' ',
#  'Transaction Category',
#  ' ',
#  ' ',
#  ' ',
#  'Trade Date',
#  ' ',
#  'Units',
#  ' ',
#  'Net Amount',
#  ' ',
#  'ISIN',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Transaction Type',
#  ' ',
#  ' ',
#  ' ',
#  'Contractual S',
#  '/D',
#  ' ',
#  'Curr',
#  'ent Fa',
#  'ce',
#  ' ',
#  ' ',
#  'OCC ID',
#  ' ',
#  'Coupon Rate',
#  ' ',
#  'Mat',
#  'urity Date',
#  ' ',
#  'Pool Number',
#  ' ',
#  'Transaction Status',
#  ' ',
#  'Age (',
#  'Da',
#  'ys',
#  ')',
#  ' ',
#  'Transaction Number',
#  ' ',
#  'Actual S/D',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Fail Description',
#  ' ',
#  ' ',
#  ' ',
#  'Broker',
#  ' ',
#  ' ',
#  ' ',
#  'Autosettle Date',
#  ' ',
#  ' ',
#  ' ',
#  'Trade Date',
#  ': 19',
#  '-',
#  'Se',
#  'p',
#  '-',
#  '2017 CCY:',
#  ' ',
#  'EUR',
#  ' ',
#  ' ',
#  'Transaction Category: ',
#  'SALE ',
#  'Transaction Status: Settled',
#  ' ',
#  '7508927',
#  ' ',
# ...

# %%
x=page.split('\n')
tot=len(x)+(16-len(x)%16)
tot
y=[]
for i in range(tot):
    if i<len(x):
        y.append(x[i])
    else:
        y.append("")

# %%
g=np.array(y).reshape(34,16)

# %%
pd.DataFrame(g)
# Out:
#                          0                            1  \
# 0              Security ID
# 1                     ISIN
# 2                                                OCC ID
# 3                                    Transaction Number
# 4          Autosettle Date
# 5                    SALE   Transaction Status: Settled
# 6                        -                         2017
# 7                       21                            -
# 8                                                    21
# 9
# 10  Transaction Category:                         SALE
# 11                     Oct                            -
# 12
# 13                                                    2
# 14                                             BROKER A
# 15                     EUR
# 16                                                   07
# 17
# 18
# 19
# 20                     Nov                            -
# 21                                                 SALE
# ...

# %%
x=page.split('\n')
x
# Out:
# ['Security ID',
#  ' ',
#  'Security Name',
#  ' ',
#  ' ',
#  ' ',
#  'Transaction Category',
#  ' ',
#  ' ',
#  ' ',
#  'Trade Date',
#  ' ',
#  'Units',
#  ' ',
#  'Net Amount',
#  ' ',
#  'ISIN',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Transaction Type',
#  ' ',
#  ' ',
#  ' ',
#  'Contractual S',
#  '/D',
#  ' ',
#  'Curr',
#  'ent Fa',
#  'ce',
#  ' ',
#  ' ',
#  'OCC ID',
#  ' ',
#  'Coupon Rate',
#  ' ',
#  'Mat',
#  'urity Date',
#  ' ',
#  'Pool Number',
#  ' ',
#  'Transaction Status',
#  ' ',
#  'Age (',
#  'Da',
#  'ys',
#  ')',
#  ' ',
#  'Transaction Number',
#  ' ',
#  'Actual S/D',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Fail Description',
#  ' ',
#  ' ',
#  ' ',
#  'Broker',
#  ' ',
#  ' ',
#  ' ',
#  'Autosettle Date',
#  ' ',
#  ' ',
#  ' ',
#  'Trade Date',
#  ': 19',
#  '-',
#  'Se',
#  'p',
#  '-',
#  '2017 CCY:',
#  ' ',
#  'EUR',
#  ' ',
#  ' ',
#  'Transaction Category: ',
#  'SALE ',
#  'Transaction Status: Settled',
#  ' ',
#  '7508927',
#  ' ',
# ...

# %%
Units=[]
for i in x:
    if i[-5:]=="0 EUR":
        Units.append(i[:-4])

# %%
#***********Part2
# Out:
# ['25,000.0000000',
#  ',000.0000000',
#  ',000.0000000',
#  ',000.0000000',
#  ',000.0000000']

# %%
import requests
from bs4 import BeautifulSoup

main_url = "https://www.sec.gov/Archives/edgar/data/1484018/000148401818000039/0001484018-18-000039.txt"

re = requests.get(main_url)
soup = BeautifulSoup(re.text, "html.parser")
city_tags = soup.find_all('a', class_="nav-title")  # Bottom page not loaded dynamycally

# %%
soup
# Out:
# <sec-document>0001484018-18-000039.txt : 20180913
# <sec-header>0001484018-18-000039.hdr.sgml : 20180913
# <acceptance-datetime>20180913130145
# ACCESSION NUMBER:		0001484018-18-000039
# CONFORMED SUBMISSION TYPE:	N-CEN
# PUBLIC DOCUMENT COUNT:		3
# CONFORMED PERIOD OF REPORT:	20180630
# FILED AS OF DATE:		20180913
# EFFECTIVENESS DATE:		20180913
#
# FILER:
#
# 	COMPANY DATA:
# 		COMPANY CONFORMED NAME:			Spinnaker ETF Series
# 		CENTRAL INDEX KEY:			0001484018
# 		IRS NUMBER:				000000000
# 		STATE OF INCORPORATION:			DE
# 		FISCAL YEAR END:			0831
#
# 	FILING VALUES:
# 		FORM TYPE:		N-CEN
# 		SEC ACT:		1940 Act
# 		SEC FILE NUMBER:	811-22398
# 		FILM NUMBER:		181068502
#
# 	BUSINESS ADDRESS:
# 		STREET 1:		116 SOUTH FRANKLIN STREET
# 		STREET 2:		POST OFFICE BOX 69
# 		CITY:			ROCKY MOUNT
# 		STATE:			NC
# 		ZIP:			27802-0069
# 		BUSINESS PHONE:		252-972-9922
#
# 	MAIL ADDRESS:
# 		STREET 1:		116 SOUTH FRANKLIN STREET
# 		STREET 2:		POST OFFICE BOX 69
# 		CITY:			ROCKY MOUNT
# ...
